# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings   

warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('../data/creditcard.csv')

# %%
print('Data Shape-',data.shape)
data.head(10)
# Out:
# Data Shape- (568630, 31)
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
# 5   5  0.025302 -0.140514  1.191138 -0.707979  0.430490  0.458973  0.611050
# 6   6  1.016482 -0.397181  0.497868 -0.144463  0.331022  0.629243  0.431262
# 7   7 -0.051306 -0.007194  1.139941 -0.877880  0.684668  0.714326  0.892615
# 8   8 -0.130680 -0.349547  0.425786 -0.760444  1.702777  2.324816  0.568968
# 9   9  0.058419 -0.093507  1.117270 -0.735172  0.466111  0.332371  0.683425
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
# ...

# %%
data.describe().plot(kind='bar', figsize=(20, 10), title='Data Description')
plt.xticks(rotation=45)
plt.show()

data.describe().T
# Out:
#            count          mean            std        min            25%  \
# id      568630.0  2.843145e+05  164149.486121   0.000000  142157.250000
# V1      568630.0 -5.638058e-17       1.000001  -3.495584      -0.565286
# V2      568630.0 -1.323544e-16       1.000001 -49.966572      -0.486678
# V3      568630.0 -3.518788e-17       1.000001  -3.183760      -0.649299
# V4      568630.0 -2.879008e-17       1.000001  -4.951222      -0.656020
# V5      568630.0  7.197521e-18       1.000001  -9.952786      -0.293496
# V6      568630.0 -3.838678e-17       1.000001 -21.111108      -0.445871
# V7      568630.0 -3.198898e-17       1.000001  -4.351839      -0.283533
# V8      568630.0  2.069287e-17       1.000001 -10.756342      -0.192257
# V9      568630.0  9.116859e-17       1.000001  -3.751919      -0.568745
# V10     568630.0  1.991314e-16       1.000001  -3.163276      -0.590101
# V11     568630.0 -1.599449e-17       1.000001  -5.954723      -0.701449
# ...

# %%
data.isna().sum()
# Out:
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize=[20,10])
sns.heatmap(data.corr(),cmap='crest',annot=True)
plt.show()

# %% [markdown]
# Few features have high co-relation among different features.
#
#
# V17 and V18 are higly co-related.
# V16 and V17 are higly co-related.
# V14 has a negative corelation with V4.
# V12 is also negatively co-related with V10 and V11.
# V11 is ngetively co-related with V10 and positvely with V4.
# V3 is positevely co-related with V10 and V12.
# V9 and V10 are also positively co-related.

# %%
data.skew()
# Out:
# id       -6.579536e-16
# V1       -8.341717e-02
# V2       -1.397952e+00
# V3        1.462221e-02
# V4       -4.416893e-02
# V5        1.506414e+00
# V6       -2.016110e-01
# V7        1.902687e+01
# V8        2.999722e-01
# V9        1.710575e-01
# V10       7.404136e-01
# V11      -2.089056e-02
# V12       6.675895e-02
# V13       1.490639e-02
# V14       2.078348e-01
# V15       1.123298e-02
# V16       2.664070e-01
# V17       3.730610e-01
# V18       1.291911e-01
# V19      -1.017123e-02
# V20      -1.556460e+00
# V21      -1.089833e-01
# V22       3.185295e-01
# V23      -9.968746e-02
# V24       6.608974e-02
# V25       2.300804e-02
# V26      -1.895874e-02
# V27       2.755452e+00
# V28       1.724978e+00
# Amount    1.655585e-03
# Class     0.000000e+00
# dtype: float64

# %% [markdown]
# Features like V1,V10,V23 are highly negatively skewed.
# We will see the distribution of some of these features.

# %%
data['Amount'].plot.box()
plt.show()

# %%
sns.kdeplot(data=data['Amount'], shade=True)
plt.show()

# %%
paper, axes = plt.subplots(2, 2, figsize=(20, 10))
data['V1'].plot(kind='hist', ax=axes[0,0], title='Distribution of V1')
data['V10'].plot(kind='hist', ax=axes[0,1], title='Distribution of V10')
data['V12'].plot(kind='hist', ax=axes[1,0], title='Distribution of V12')
data['V23'].plot(kind='hist', ax=axes[1,1], title='Distribution of V23')
plt.tight_layout()
plt.show()

# %%
data['Class'].value_counts().plot.pie(explode=[0.1,0],shadow=True, legend= True,startangle =45)
plt.title('Distribution of Class',size=14)
plt.show()
